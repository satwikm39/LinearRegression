# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline
from sklearn import linear_model

# %%
df=pd.read_csv("housingdata.csv",header=None)

# %%
housing_colnames = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df.columns=housing_colnames
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ## SKLEARN

# %%
X=df[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']].values
y=df['MEDV'].values

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
reg=LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=reg.predict(X)

# %%
dff = pd.DataFrame({'Actual': y, 'Predicted': y_pred})
df1 = dff.head(25)
df1
# Out:
#     Actual  Predicted
# 0     24.0  30.003843
# 1     21.6  25.025562
# 2     34.7  30.567597
# 3     33.4  28.607036
# 4     36.2  27.943524
# 5     28.7  25.256284
# 6     22.9  23.001808
# 7     27.1  19.535988
# 8     16.5  11.523637
# 9     18.9  18.920262
# 10    15.0  18.999497
# 11    18.9  21.586796
# 12    21.7  20.906522
# 13    20.4  19.552903
# 14    18.2  19.283482
# 15    19.9  19.297483
# 16    23.1  20.527510
# 17    17.5  16.911401
# 18    20.2  16.178011
# 19    18.2  18.406136
# 20    13.6  12.523858
# 21    19.6  17.671037
# 22    15.2  15.832881
# 23    14.5  13.806285
# 24    15.6  15.678338

# %% [markdown]
# ## GRADIENT DESCENT

# %%
#mean normalization
#my_data = (df - df.mean())/df.std()
my_data=df
my_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#setting the matrixes
X2 = my_data.iloc[:,0:13]
ones = np.ones([X2.shape[0],1])
X2 = np.concatenate((ones,X2),axis=1)

y2 = my_data.iloc[:,13:14].values 
theta = np.zeros([1,14])

xtemp=df.iloc[:,0:13]
ones = np.ones([xtemp.shape[0],1])
xtemp = np.concatenate((ones,xtemp),axis=1)

# %%
t0=[]
t1=[]
cst=[]

# %%
#computecost
def computeCost(X2,y2,theta):
    tobesummed = np.power(((X2 @ theta.T)-y2),2)
#     print(tobesummed)
    return np.sum(tobesummed)/(2 * len(X2))

def gradientDescent(X2,y2,theta,iters,alpha):
    cost = np.zeros(iters)
    #print(X2.shape)
    for i in range(iters):
        theta = theta - (alpha/len(X2)) * np.sum(X2 * (X2 @ theta.T - y2), axis=0)
        cost[i] = computeCost(X2, y2, theta)
        t0.append(theta[0,0])
        t1.append(theta[0,1])
        cst.append(cost[i])

    return theta,cost

# %%
#set hyper parameters
alpha = 0.000001
iters = 10000
theta = np.zeros([1,14])

# %%
theta,cost = gradientDescent(X2,y2,theta,iters,alpha)
print(theta)
# Out:
# [[ 0.00592    -0.06393063  0.12999067 -0.037365    0.00385067  0.00209638
#    0.0704665   0.06195775  0.013075    0.0032703   0.00145345  0.04773669
#    0.04866925 -0.19360688]]

# %%
finalCost = computeCost(X2,y2,theta)
print(finalCost)

h=xtemp @ theta.T
# Out:
# 31.596591409570713

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ## Normal Equation

# %%
ntheta = (np.linalg.pinv(X2.T@X2)@(X2.T))@y

# %%
n_pred=ntheta@X2.T

# %%
y_pred=y_pred.reshape(506,1)
n_pred=n_pred.reshape(506,1);

# %%
df['pred1']=y_pred
df['pred2']=n_pred
df['pred3']=h

# %%
a=df[['pred1']]
b=df[['pred2']]
c=df[['pred3']]

# %%
r1=linear_model.LinearRegression()
r1.fit(y_pred,n_pred)

# %matplotlib inline
plt.xlabel('normal eqn', fontsize=20)
plt.ylabel('skl', fontsize=20)
plt.plot(df.pred2,df.pred1,color='blue')
plt.plot(df.pred2,r1.predict(b),color='red')

# %%
r2=linear_model.LinearRegression()
r2.fit(y_pred,h)

# %matplotlib inline
plt.xlabel('Gradient Descent', fontsize=20)
plt.ylabel('skl', fontsize=20)
plt.scatter(df.pred3,df.pred1,color='blue')
plt.plot(df.pred3,r2.predict(c),color='red')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_trisurf(t0,t1,cst,linewidth=0.2,antialiased=True)
plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
dff = pd.DataFrame({'t0': t0, 't1': t1,'cost':cst})

# %%
data = [
    go.Surface(
        x=Xs, y=Ys, z=Zs
    )
]
layout = go.Layout(
    title='comparison',
    autosize=False,
    width=500,
    height=500,
    margin=dict(
        l=65,
        r=50,
        b=65,
        t=90
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='elevations-3d-surface')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-33-f1bbc13cb9cc> in <module>
#      17 )
#      18 fig = go.Figure(data=data, layout=layout)
# ---> 19 py.iplot(fig, filename='elevations-3d-surface')
#
# ~\Anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in iplot(figure_or_data, **plot_options)
#     157     if 'auto_open' not in plot_options:
#     158         plot_options['auto_open'] = False
# --> 159     url = plot(figure_or_data, **plot_options)
#     160
#     161     if isinstance(figure_or_data, dict):
#
# ~\Anaconda3\lib\site-packages\chart_studio\plotly\plotly.py in plot(figure_or_data, validate, **plot_options)
#     255     data = fig.get('data', [])
#     256     plot_options['layout'] = fig.get('layout', {})
# --> 257     response = v1.clientresp(data, **plot_options)
#     258
#     259     # Check if the url needs a secret key
#
# ~\Anaconda3\lib\site-packages\chart_studio\api\v1\clientresp.py in clientresp(data, **kwargs)
#      37
#      38     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 39     response = request('post', url, data=payload)
#      40
#      41     # Old functionality, just keeping it around.
#
# ~\Anaconda3\lib\site-packages\retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# ~\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     204
#     205             if not self.should_reject(attempt):
# --> 206                 return attempt.get(self._wrap_exception)
#     207
#     208             delay_since_first_attempt_ms = int(round(time.time() * 1000)) - start_time
#
# ~\Anaconda3\lib\site-packages\retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# ~\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~\Anaconda3\lib\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\chart_studio\api\v1\utils.py in request(method, url, **kwargs)
#      90         content = response.content if response else 'No content'
#      91         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 92     validate_response(response)
#      93     return response
#
# ~\Anaconda3\lib\site-packages\chart_studio\api\v1\utils.py in validate_response(response)
#      39         message = content if content else 'No Content'
#      40
# ---> 41     raise exceptions.PlotlyRequestError(message, status_code, content)
#      42
#      43
#
# PlotlyRequestError: Aw, snap! You tried to use our API as the user 'satwikm', but the supplied API key doesn't match our records. You can view your API key at https://plot.ly/settings/api
#
# You're most likely getting this message because your local credentials file isn't synced with the Plotly server you're communicating with.
#
# Go to https://plot.ly/<language>/getting-started (e.g., https://plot.ly/python/getting-started) for more information.
#
# Make sure that you're logged in as satwikm.
#
# Need help? Please try searching Plotly's <a href='http://stackoverflow.com/questions/tagged/plotly'>Stack Overflow channel</a>.

# %%
crim=df['CRIM'].values
zn=df['ZN'].values
X = np.column_stack((np.ones(len(crim)), crim))
y = zn

# %%
def compute_cost(X, y, theta):
    return np.sum(np.square(np.matmul(X, theta) - y)) / (2 * len(y))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

Xs, Ys = np.meshgrid(np.linspace(0.00002, 0.006, 50), np.linspace(-0.06, 0.00008,50))
Zs = np.array([compute_cost(X, y, [t0, t1]) for t0, t1 in zip(np.ravel(Xs), np.ravel(Ys))])
Zs = np.reshape(Zs, Xs.shape)

fig = plt.figure(figsize=(7,7))
ax = fig.gca(projection="3d")
ax.set_xlabel(r't0')
ax.set_ylabel(r't1')
ax.set_zlabel(r'cost')
ax.view_init(elev=25, azim=40)
ax.plot_surface(Xs, Ys, Zs, cmap=cm.rainbow)
